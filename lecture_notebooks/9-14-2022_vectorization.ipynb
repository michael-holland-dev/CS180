# %%
import numpy as np
from scipy import misc

# %%
import matplotlib.pyplot as plt

# %%
img = misc.face()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (768, 1024, 3)

# %%
plt.imshow( img )

# %%
plt.imshow( img[:,:,0] )

# %%
plt.imshow(img[:,:,1])

# %%
plt.imshow(img[:,:,2])

# %%
plt.imshow( np.random.rand(768,1024) )

# %%
img[0,0,0]
# Out:
# 121

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow( img[ :,:,0:1 ], cmap="Greys" )
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-681c1d7556bf> in <module>
# ----> 1 plt.imshow( img[ :,:,0:1 ], cmap="Greys" )
#       2 plt.colorbar()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
print( img[:,:,0].shape )
print( img[:,:,0:1].shape )
# Out:
# (768, 1024)
# (768, 1024, 1)

# %%
plt.imshow( img.astype('float32')/255.0 )

# %%
A = np.random.randn( 100, 3 )

# %%
C = A+B
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-8845ff27cb45> in <module>
# ----> 1 C = A+B
#
# ValueError: operands could not be broadcast together with shapes (100,3) (50,3)

# %%
D = np.random.randn( 5, 6, 3 )
N = np.ones( (5,6,3) )

D.sum(axis=0) / N.sum(axis=0)
# Out:
# array([[-0.11192236, -0.27243011, -0.6578214 ],
#        [ 0.05938065, -0.15655234, -0.06675505],
#        [-0.48883543, -0.2885632 ,  0.36737298],
#        [ 0.19509228,  0.91440727, -0.63644171],
#        [-0.34259578,  0.47070748,  0.67091876],
#        [-0.91121721, -0.26867668, -0.1318461 ]])
